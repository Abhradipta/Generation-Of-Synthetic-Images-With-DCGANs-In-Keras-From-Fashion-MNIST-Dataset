# %% [markdown]
# <h2 align=center>Generation Of Synthetic Images With DCGANs In Keras From Fashion MNIST Dataset</h2>

# %% [markdown]
# ## Importing Necessary Libraries

# %%
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
import numpy as np
import plot_utils
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython import display
print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.3.0

# %% [markdown]
# ## Loading and Preprocessing the Data

# %%
(x_train, y_train),(x_test, y_test)=tf.keras.datasets.fashion_mnist.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# ## Creation Of Batches Of Training Data

# %%
batch_size=32
dataset=tf.data.Dataset.from_tensor_slices(x_train).shuffle(1000)
dataset=dataset.batch(batch_size,drop_remainder=True).prefetch(1)

# %% [markdown]
# ## Building The Generator Network For DCGAN

# %% [markdown]
# <h1>GAN</h1>
#
# ![DCGAN.png](data:image/png;base64,...)

# %% [markdown]
# **Generator** is an upsampling network with fractionally-strided convolutions
#
# **Discriminator** is a convolutional network

# %% [markdown]
# Architecture For Stable Deep Convolutional GANs:
#
# - Replace any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# - Use batchnorm in both the generator and the discriminator.
# - Remove fully connected hidden layers for deeper architectures.
# - Use ReLU activation in generator for all layers expect for the output, which uses Tanh.
# - Use LeakyReLU activation in the discriminator for all layers.

# %%
num_features=100
generator=keras.models.Sequential([
    keras.layers.Dense(7*7*128, input_shape=[num_features]),
    keras.layers.Reshape([7,7,128]),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2DTranspose(64,(5,5),(2,2),padding='same', activation='selu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2DTranspose(1,(5,5),(2,2), padding='same',activation='tanh')
])

# %%
noise=tf.random.normal(shape=[1, num_features])
generated_image=generator(noise, training=False)
plot_utils.show(generated_image, 1)

# %% [markdown]
# ## Building The Discriminator Network For DCGAN

# %%
discriminator=keras.models.Sequential([
    keras.layers.Conv2D(64,(5,5),(2,2), padding='same',input_shape=[28,28,1]),
    keras.layers.LeakyReLU(0.2),
    keras.layers.Dropout(0.3),
    keras.layers.Conv2D(256,(5,5),(2,2), padding='same'),
    keras.layers.LeakyReLU(0.2),
    keras.layers.Dropout(0.3),
    keras.layers.Flatten(),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
decision=discriminator(generated_image)
print(decision)
# Out:
# tf.Tensor([[0.49974704]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ## Compiling The Deep Convolutional Generative Adversarial Network (DCGAN)

# %%
discriminator.compile(loss='binary_crossentropy', optimizer='rmsprop')
discriminator.trainable=False
gan=keras.models.Sequential([
    generator, discriminator
])
gan.compile(loss='binary_crossentropy', optimizer='rmsprop')

# %% [markdown]
# ## Defining Training Procedure

# %%
seed=tf.random.normal(shape=[batch_size,100])

# %%
def train_dcgan(gan, dataset, batch_size, num_features, epochs=5):
    generator, discriminator=gan.layers
    for epoch in tqdm(range(epochs)):
        print("Epochs {}/{}".format(epoch+1,epochs))
        for X_batch in dataset:
            noise=tf.random.normal(shape=[batch_size, num_features])
            generated_images=generator(noise)
            X_fake_and_real=tf.concat([generated_images, X_batch], axis=0)
            y1=tf.constant([[0.]]*batch_size+[[1.]]*batch_size)
            discriminator.trainable=True
            discriminator.train_on_batch(X_fake_and_real, y1)
            y2=tf.constant([[1.]]*batch_size)
            discriminator.trainable=False
            gan.train_on_batch(noise,y2)
        display.clear_output(wait=True)
        generate_and_save_images(generator, epoch+1, seed)
    display.clear_output(wait=True)
    generate_and_save_images(generator, epochs, seed)

# %%
## Source https://www.tensorflow.org/tutorials/generative/dcgan#create_a_gif
def generate_and_save_images(model, epoch, test_input):
    predictions = model(test_input, training=False)
    fig = plt.figure(figsize=(10,10))
    
    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='binary')
        plt.axis('off')
    plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
    plt.show()

# %% [markdown]
# ## Training DCGAN

# %%
x_train_dcgan=x_train.reshape(-1,28,28,1)*2. -1

# %%
batch_size=32
dataset=tf.data.Dataset.from_tensor_slices(x_train_dcgan).shuffle(1000)
dataset=dataset.batch(batch_size, drop_remainder=True).prefetch(1)

# %%
# %%time
train_dcgan(gan, dataset, batch_size, num_features, epochs=100)
# Out:
# CPU times: user 52min, sys: 3min 1s, total: 55min 2s
# Wall time: 57min 34s

# %% [markdown]
# ## Generating Synthetic Images With DCGAN

# %%
noise=tf.random.normal(shape=[batch_size, num_features])
generated_images=generator(noise)
plot_utils.show(generated_images, 8)

# %%
## Source: https://www.tensorflow.org/tutorials/generative/dcgan#create_a_gif

import imageio
import glob

anim_file = 'dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('image*.png')
    filenames = sorted(filenames)
    last = -1
    for i,filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

import IPython
display.Image(filename=anim_file)

# %%
# !zip results1.zip *
# Out:
#   adding: dcgan.gif (deflated 14%)
#   adding: DCGAN.png (deflated 3%)
#   adding: image_at_epoch_0001.png (deflated 11%)
#   adding: image_at_epoch_0002.png (deflated 12%)
#   adding: image_at_epoch_0003.png (deflated 12%)
#   adding: image_at_epoch_0004.png (deflated 11%)
#   adding: image_at_epoch_0005.png (deflated 11%)
#   adding: image_at_epoch_0006.png (deflated 13%)
#   adding: image_at_epoch_0007.png (deflated 12%)
#   adding: image_at_epoch_0008.png (deflated 13%)
#   adding: image_at_epoch_0009.png (deflated 12%)
#   adding: image_at_epoch_0010.png (deflated 12%)
#   adding: image_at_epoch_0011.png (deflated 12%)
#   adding: image_at_epoch_0012.png (deflated 13%)
#   adding: image_at_epoch_0013.png (deflated 12%)
#   adding: image_at_epoch_0014.png (deflated 13%)
#   adding: image_at_epoch_0015.png (deflated 12%)
#   adding: image_at_epoch_0016.png (deflated 12%)
#   adding: image_at_epoch_0017.png (deflated 11%)
#   adding: image_at_epoch_0018.png (deflated 12%)
#   adding: image_at_epoch_0019.png (deflated 13%)
#   adding: image_at_epoch_0020.png (deflated 12%)
#   adding: image_at_epoch_0021.png (deflated 11%)
#   adding: image_at_epoch_0022.png (deflated 11%)
#   adding: image_at_epoch_0023.png (deflated 12%)
#   adding: image_at_epoch_0024.png (deflated 12%)
#   adding: image_at_epoch_0025.png (deflated 11%)
#   adding: image_at_epoch_0026.png (deflated 12%)
#   adding: image_at_epoch_0027.png (deflated 12%)
#   adding: image_at_epoch_0028.png (deflated 13%)
#   adding: image_at_epoch_0029.png (deflated 12%)
#   adding: image_at_epoch_0030.png (deflated 12%)
#   adding: image_at_epoch_0031.png (deflated 11%)
#   adding: image_at_epoch_0032.png (deflated 12%)
#   adding: image_at_epoch_0033.png (deflated 12%)
#   adding: image_at_epoch_0034.png (deflated 11%)
#   adding: image_at_epoch_0035.png (deflated 11%)
#   adding: image_at_epoch_0036.png (deflated 11%)
#   adding: image_at_epoch_0037.png (deflated 11%)
#   adding: image_at_epoch_0038.png (deflated 13%)
#   adding: image_at_epoch_0039.png (deflated 13%)
#   adding: image_at_epoch_0040.png (deflated 11%)
#   adding: image_at_epoch_0041.png (deflated 12%)
#   adding: image_at_epoch_0042.png (deflated 13%)
#   adding: image_at_epoch_0043.png (deflated 12%)
#   adding: image_at_epoch_0044.png (deflated 12%)
#   adding: image_at_epoch_0045.png (deflated 12%)
#   adding: image_at_epoch_0046.png (deflated 12%)
#   adding: image_at_epoch_0047.png (deflated 12%)
#   adding: image_at_epoch_0048.png (deflated 13%)
#   adding: image_at_epoch_0049.png (deflated 11%)
#   adding: image_at_epoch_0050.png (deflated 12%)
#   adding: image_at_epoch_0051.png (deflated 12%)
#   adding: image_at_epoch_0052.png (deflated 12%)
#   adding: image_at_epoch_0053.png (deflated 12%)
#   adding: image_at_epoch_0054.png (deflated 12%)
#   adding: image_at_epoch_0055.png (deflated 12%)
#   adding: image_at_epoch_0056.png (deflated 12%)
#   adding: image_at_epoch_0057.png (deflated 12%)
#   adding: image_at_epoch_0058.png (deflated 13%)
#   adding: image_at_epoch_0059.png (deflated 12%)
#   adding: image_at_epoch_0060.png (deflated 12%)
#   adding: image_at_epoch_0061.png (deflated 12%)
#   adding: image_at_epoch_0062.png (deflated 12%)
#   adding: image_at_epoch_0063.png (deflated 13%)
#   adding: image_at_epoch_0064.png (deflated 12%)
#   adding: image_at_epoch_0065.png (deflated 13%)
#   adding: image_at_epoch_0066.png (deflated 12%)
#   adding: image_at_epoch_0067.png (deflated 12%)
#   adding: image_at_epoch_0068.png (deflated 12%)
#   adding: image_at_epoch_0069.png (deflated 12%)
#   adding: image_at_epoch_0070.png (deflated 12%)
#   adding: image_at_epoch_0071.png (deflated 12%)
#   adding: image_at_epoch_0072.png (deflated 12%)
#   adding: image_at_epoch_0073.png (deflated 13%)
#   adding: image_at_epoch_0074.png (deflated 13%)
#   adding: image_at_epoch_0075.png (deflated 12%)
#   adding: image_at_epoch_0076.png (deflated 12%)
#   adding: image_at_epoch_0077.png (deflated 12%)
#   adding: image_at_epoch_0078.png (deflated 12%)
#   adding: image_at_epoch_0079.png (deflated 12%)
#   adding: image_at_epoch_0080.png (deflated 12%)
#   adding: image_at_epoch_0081.png (deflated 12%)
#   adding: image_at_epoch_0082.png (deflated 11%)
#   adding: image_at_epoch_0083.png (deflated 12%)
#   adding: image_at_epoch_0084.png (deflated 12%)
#   adding: image_at_epoch_0085.png (deflated 12%)
#   adding: image_at_epoch_0086.png (deflated 12%)
#   adding: image_at_epoch_0087.png (deflated 12%)
#   adding: image_at_epoch_0088.png (deflated 12%)
#   adding: image_at_epoch_0089.png (deflated 12%)
#   adding: image_at_epoch_0090.png (deflated 12%)
#   adding: image_at_epoch_0091.png (deflated 12%)
#   adding: image_at_epoch_0092.png (deflated 12%)
#   adding: image_at_epoch_0093.png (deflated 12%)
#   adding: image_at_epoch_0094.png (deflated 12%)
#   adding: image_at_epoch_0095.png (deflated 12%)
#   adding: image_at_epoch_0096.png (deflated 12%)
#   adding: image_at_epoch_0097.png (deflated 12%)
#   adding: image_at_epoch_0098.png (deflated 12%)
#   adding: image_at_epoch_0099.png (deflated 13%)
#   adding: image_at_epoch_0100.png (deflated 12%)
#   adding: photo.jpg (deflated 0%)
#   adding: plot_utils.py (deflated 46%)
#   adding: __pycache__/ (stored 0%)
#   adding: results.zip (stored 0%)
#   adding: sample_data/ (stored 0%)
